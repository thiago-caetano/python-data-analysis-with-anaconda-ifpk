# %%
import pandas as pd

# %%
dados = {
    "Nome": ["Ana", "Bruno", "Carlos", "Diana", "Eduardo", "Fernanda", "Gabriel", "Helena"],
    "Idade": [20, 25, 30, 22, 28, 24, 35, 27],
    "Curso": ["Python", "Excel", "Python", "Power BI", "Python", "Excel", "Power BI", "Python"],
    "Nota": [8.5, 6.0, 7.2, 9.1, 5.5, 7.8, 6.9, 10.0],
    "Mensalidade": [300, 250, 300, 400, 300, 250, 400, 300]
}

df = pd.DataFrame(dados)

# %%
# 1. Exiba o DataFrame completo

print (df)
# Out:
#        Nome  Idade     Curso  Nota  Mensalidade
# 0       Ana     20    Python   8.5          300
# 1     Bruno     25     Excel   6.0          250
# 2    Carlos     30    Python   7.2          300
# 3     Diana     22  Power BI   9.1          400
# 4   Eduardo     28    Python   5.5          300
# 5  Fernanda     24     Excel   7.8          250
# 6   Gabriel     35  Power BI   6.9          400
# 7    Helena     27    Python  10.0          300

# %%
# 2. Mostre as 5 primeiras linhas

df.head()
# Out:
#       Nome  Idade     Curso  Nota  Mensalidade
# 0      Ana     20    Python   8.5          300
# 1    Bruno     25     Excel   6.0          250
# 2   Carlos     30    Python   7.2          300
# 3    Diana     22  Power BI   9.1          400
# 4  Eduardo     28    Python   5.5          300

# %%
# 3. Mostre as 3 últimas linhas.

df.tail(3)
# Out:
#        Nome  Idade     Curso  Nota  Mensalidade
# 5  Fernanda     24     Excel   7.8          250
# 6   Gabriel     35  Power BI   6.9          400
# 7    Helena     27    Python  10.0          300

# %%
# 4. Exiba apenas a coluna Nome.

df ["Nome"]
# Out:
# 0         Ana
# 1       Bruno
# 2      Carlos
# 3       Diana
# 4     Eduardo
# 5    Fernanda
# 6     Gabriel
# 7      Helena
# Name: Nome, dtype: object

# %%
# 5. Exiba as colunas Nome e Curso.

df [["Nome", "Curso"]]
# Out:
#        Nome     Curso
# 0       Ana    Python
# 1     Bruno     Excel
# 2    Carlos    Python
# 3     Diana  Power BI
# 4   Eduardo    Python
# 5  Fernanda     Excel
# 6   Gabriel  Power BI
# 7    Helena    Python

# %%
# 6. Mostre os alunos do curso de Python.

df [df["Curso"] == "Python"]
# Out:
#       Nome  Idade   Curso  Nota  Mensalidade
# 0      Ana     20  Python   8.5          300
# 2   Carlos     30  Python   7.2          300
# 4  Eduardo     28  Python   5.5          300
# 7   Helena     27  Python  10.0          300

# %%
# 7. Mostre os alunos com nota maior ou igual a 7.

df[df["Nota"] >= 7]["Nome"]
# Out:
# 0         Ana
# 2      Carlos
# 3       Diana
# 5    Fernanda
# 7      Helena
# Name: Nome, dtype: object

# %%
# 8. Mostre os alunos com idade maior que 25.

df[df["Idade"] >= 25]
# Out:
#       Nome  Idade     Curso  Nota  Mensalidade
# 1    Bruno     25     Excel   6.0          250
# 2   Carlos     30    Python   7.2          300
# 4  Eduardo     28    Python   5.5          300
# 6  Gabriel     35  Power BI   6.9          400
# 7   Helena     27    Python  10.0          300

# %%
# 9. Calcule a média das notas. # 10. # 11.
print ("media", df["Nota"].mean())
print ("maior", df["Nota"].max())
print ("minimo", df["Nota"].min())
# Out:
# media 7.625
# maior 10.0
# minimo 5.5

# %%
df[df["Nota"] >= df["Nota"].mean()]
# Out:
#        Nome  Idade     Curso  Nota  Mensalidade  Situação
# 0       Ana     20    Python   8.5          300  Aprovado
# 3     Diana     22  Power BI   9.1          400  Aprovado
# 5  Fernanda     24     Excel   7.8          250  Aprovado
# 7    Helena     27    Python  10.0          300  Aprovado

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
vendas = pd.Series ([150, 230, 90, 400, 320, 180, 600])

vendas.plot(kind="bar")

plt.title ("Vendas ao longo do Tempo")
plt.xlabel ("Dias")
plt.ylabel ("Valor")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 12. Crie uma nova coluna chamada Situação: Aprovado se Nota >= 7 e Reprovado se Nota < 7.

df ["Situação"] = np.where(df["Nota"] >=7, "Aprovado", "Reprovado")

df
# Out:
#        Nome  Idade     Curso  Nota  Mensalidade   Situação
# 0       Ana     20    Python   8.5          300   Aprovado
# 1     Bruno     25     Excel   6.0          250  Reprovado
# 2    Carlos     30    Python   7.2          300   Aprovado
# 3     Diana     22  Power BI   9.1          400   Aprovado
# 4   Eduardo     28    Python   5.5          300  Reprovado
# 5  Fernanda     24     Excel   7.8          250   Aprovado
# 6   Gabriel     35  Power BI   6.9          400  Reprovado
# 7    Helena     27    Python  10.0          300   Aprovado

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
